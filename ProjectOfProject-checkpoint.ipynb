# %% [markdown]
# # This is just exploring

# %%
import matplotlib.pyplot as plt

income = float(input("Please enter your income:"))
food = float(input('Please enter amount on food:'))
insurace = float(input('Please enter amount on Insurance:'))
mortgage = float(input('Please enter amount on Mortgage:'))
saving = (totalIncome) - (food + Insurace + mortgage)



labels = 'Income','Food', 'Insurace', 'Mortgage', 'Saving'
sizes = income, food, insurace, mortgage, saving
colors = ['Green','gold', 'yellowgreen','lightcoral', 'lightskyblue']
#explode = (0.1, 0, 0, 0) explode 1st sloce

plt.pie(sizes, labels = labels, colors = colors, autopct ='%1.1f%%', shadow =True, startangle =140) #
plt.axis('equal')
plt.show()
# Out:
# Please enter your income:500
# Please enter amount on food:350
# Please enter amount on Insurance:100
# Please enter amount on Mortgage:800
